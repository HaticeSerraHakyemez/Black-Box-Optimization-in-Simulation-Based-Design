# %%
import numpy as np
import utils.exampleFunctions as ex_func 
import utils.generalDefinitions as gen_def
import utils.models as models
import utils.samplers as samplers
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Iteration
#50 run

function_names = ex_func.function_ranges.keys()

# Her bir fonksiyon için işlemleri gerçekleştir
number_of_repeats = 5

min_iter_first = {
    "Function": [],
    "Iteration to Find Min": []
}

min_iter_second = {
    "Function": [],
    "Iteration to Find Min": []
}

min_iter_third = {
    "Function": [],
    "Iteration to Find Min": []
}

for function_name in function_names:
    if True:
        #print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_params, min_function_values, improvement, new_points_all, iteration, current_min_iter_first = active_learning.run_active_learning_constant_iterations_25(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")

                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

        if True:
            min_iter_first["Function"].append(function_name)
            min_iter_first["Iteration to Find Min"].append(current_min_iter_first)
            
            
# LHS
for function_name in function_names:
    if True:
        #print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count_second = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_params, min_function_values, improvement, new_points_all, iteration, current_min_iter_second = active_learning.run_active_learning_no_weight_adjustment_low_pred(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count_second += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

        if True:
            min_iter_second["Function"].append(function_name)
            min_iter_second["Iteration to Find Min"].append(current_min_iter_second)



# LHS
for function_name in function_names:
    if True:
        #print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count_third = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_params, min_function_values, improvement, new_points_all, iteration, current_min_iter_third = active_learning.run_active_learning_no_weight_adjustment_high_pred(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count_third += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)


        if True:
            min_iter_third["Function"].append(function_name)
            min_iter_third["Iteration to Find Min"].append(current_min_iter_third)






# Convert the dictionary to a DataFrame
min_iter_first_df = pd.DataFrame(min_iter_first)

# Convert the dictionary to a DataFrame
min_iter_second_df = pd.DataFrame(min_iter_second)

# Convert the dictionary to a DataFrame
min_iter_third_df = pd.DataFrame(min_iter_third)

plt.figure(figsize=(12, 8))

# İlk veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(min_iter_first_df["Function"], min_iter_first_df["Iteration to Find Min"])):

    # Scatter plot - kırmızı renk
    plt.scatter(i, proximity, color='red', label="Adjusted Weights" if i == 0 else '')

    # Line plot
    if i < len(min_iter_first_df["Function"]) - 1:
        plt.plot([i, i + 1], [proximity, min_iter_first_df["Iteration to Find Min"][i + 1]], color='red', linestyle='--')

# İkinci veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(min_iter_second_df["Function"], min_iter_second_df["Iteration to Find Min"])):

    # Scatter plot - mavi renk
    plt.scatter(i, proximity, color='blue', label="Low Prediction Weight" if i == 0 else '')

    # Line plot
    if i < len(min_iter_second_df["Function"]) - 1:
        plt.plot([i, i + 1], [proximity, min_iter_second_df["Iteration to Find Min"][i + 1]], color='blue', linestyle='-.')


# Üçüncü veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(min_iter_third_df["Function"], min_iter_third_df["Iteration to Find Min"])):

    # Scatter plot - mavi renk
    plt.scatter(i, proximity, color='green', label="High Prediction Weight" if i == 0 else '')

    # Line plot
    if i < len(min_iter_third_df["Function"]) - 1:
        plt.plot([i, i + 1], [proximity, min_iter_third_df["Iteration to Find Min"][i + 1]], color='green', linestyle='-.')


# Add labels and legend
plt.xlabel("Function")
plt.ylabel("Iteration to Find Min")
plt.title("Iteration to Find Min by Function")
plt.xticks(range(len(min_iter_first_df["Function"])), min_iter_first_df["Function"], rotation=75)
plt.grid(True)
plt.tight_layout()

# Show plot
plt.legend()
plt.show()
# Out:
# Convergence reached at iteration 4.
# Convergence reached at iteration 5.
# Convergence reached at iteration 4.
# Convergence reached at iteration 4.
# Convergence reached at iteration 7.
# Convergence reached at iteration 10.
# Convergence reached at iteration 17.
# Convergence reached at iteration 10.
# Convergence reached at iteration 22.
# Convergence reached at iteration 11.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 4.
# Convergence reached at iteration 2.
# Convergence reached at iteration 10.
# Convergence reached at iteration 7.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 7.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 8.
# Convergence reached at iteration 10.
# Convergence reached at iteration 4.
# Convergence reached at iteration 4.
# Convergence reached at iteration 10.
# Convergence reached at iteration 2.
# Convergence reached at iteration 10.
# Convergence reached at iteration 10.
# Convergence reached at iteration 5.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 13.
# Convergence reached at iteration 10.
# Convergence reached at iteration 5.
# Convergence reached at iteration 7.
# Convergence reached at iteration 5.
# Convergence reached at iteration 3.
# Convergence reached at iteration 5.
# Convergence reached at iteration 12.
# Convergence reached at iteration 13.
# Convergence reached at iteration 17.
# Convergence reached at iteration 8.
# Convergence reached at iteration 4.
# Convergence reached at iteration 14.
# Convergence reached at iteration 4.
# Convergence reached at iteration 11.
# Convergence reached at iteration 4.
# Convergence reached at iteration 19.
# Convergence reached at iteration 5.
# Convergence reached at iteration 13.
# Convergence reached at iteration 13.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 10.
# Convergence reached at iteration 4.
# Convergence reached at iteration 10.
# Convergence reached at iteration 7.
# Convergence reached at iteration 6.
# Convergence reached at iteration 22.
# Convergence reached at iteration 19.
# Convergence reached at iteration 10.
# Convergence reached at iteration 14.
# Convergence reached at iteration 16.
# Convergence reached at iteration 10.
# Convergence reached at iteration 23.
# Convergence reached at iteration 20.
# Convergence reached at iteration 17.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 5.
# Convergence reached at iteration 4.
# Convergence reached at iteration 2.
# Convergence reached at iteration 19.
# Convergence reached at iteration 20.
# Convergence reached at iteration 11.
# Convergence reached at iteration 5.
# Convergence reached at iteration 18.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 7.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 2.
# Convergence reached at iteration 3.
# Convergence reached at iteration 4.
# Convergence reached at iteration 4.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 19.
# Convergence reached at iteration 24.
# Convergence reached at iteration 11.
# Convergence reached at iteration 22.
# Convergence reached at iteration 24.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 7.
# Convergence reached at iteration 2.
# Convergence reached at iteration 7.
# Convergence reached at iteration 4.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 3.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 18.
# Convergence reached at iteration 6.
# Convergence reached at iteration 9.
# Convergence reached at iteration 7.
# Convergence reached at iteration 9.
# Convergence reached at iteration 7.
# Convergence reached at iteration 2.
# Convergence reached at iteration 3.
# Convergence reached at iteration 24.
# Convergence reached at iteration 18.
# Convergence reached at iteration 17.
# Convergence reached at iteration 3.
# Convergence reached at iteration 4.
# Convergence reached at iteration 2.
# Convergence reached at iteration 12.
# Convergence reached at iteration 6.
# Convergence reached at iteration 7.
# Convergence reached at iteration 4.
# Convergence reached at iteration 4.
# Convergence reached at iteration 2.
# Convergence reached at iteration 9.
# Convergence reached at iteration 21.
# Convergence reached at iteration 18.
# Convergence reached at iteration 12.
# Convergence reached at iteration 21.
# Convergence reached at iteration 6.
# Convergence reached at iteration 24.
# Convergence reached at iteration 4.
# Convergence reached at iteration 9.

# %%
plt.figure(figsize=(12, 8))

# İlk veri kümesinin çubuklarını çizme
bar_width = 0.3
index = np.arange(len(min_iter_first_df["Function"]))

plt.bar(index, min_iter_first_df["Iteration to Find Min"], bar_width, label='Adjusted Weights')

# İkinci veri kümesinin çubuklarını çizme
plt.bar(index + bar_width, min_iter_second_df["Iteration to Find Min"], bar_width, label='Low Prediction Weight')

plt.bar(index + 2* bar_width, min_iter_third_df["Iteration to Find Min"], bar_width, label='High Prediction Weight')


# Eksen etiketleri, başlık ve görsel ayarları
plt.xlabel("Function")
plt.ylabel("Objection Function Iteration to Find Min")
plt.title("Objection Function Iteration to Find Min by Function")
plt.xticks(index + bar_width / 3, min_iter_first_df["Function"], rotation=75)
plt.grid(True)
plt.tight_layout()
plt.legend()

# Grafiği gösterme
plt.show()

# %%
#Distacnes
#50 run

function_names = ex_func.function_ranges.keys()

# Her bir fonksiyon için işlemleri gerçekleştir
number_of_repeats = 5

distances_first = {
    "Function": [],
    "Distance to Min": []
}

distances_second = {
    "Function": [],
    "Distance to Min": []
}

distances_third = {
    "Function": [],
    "Distance to Min": []
}

for function_name in function_names:
    if True:
        #print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]

                    min_param = ex_func.function_min_inputs[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_params, min_function_values, improvement, new_points_all, iteration, current_min_iter_first = active_learning.run_active_learning_constant_iterations_25(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")

                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

        if True:
            distances_first["Function"].append(function_name)
            distances_first["Distance to Min"].append(gen_def.distance_btw_two_points(min_param, min_function_params)/gen_def.grid_diagonal_distance(range_param))
            
            
# LHS
for function_name in function_names:
    if True:
        #print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count_second = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]

                    min_param = ex_func.function_min_inputs[function_name]



                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_params, min_function_values, improvement, new_points_all, iteration, current_min_iter_second = active_learning.run_active_learning_no_weight_adjustment_low_pred(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count_second += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

        if True:
            distances_second["Function"].append(function_name)
            distances_second["Distance to Min"].append(gen_def.distance_btw_two_points(min_param, min_function_params)/gen_def.grid_diagonal_distance(range_param))



# LHS
for function_name in function_names:
    if True:
        #print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count_third = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]

                    min_param = ex_func.function_min_inputs[function_name]



                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_params, min_function_values, improvement, new_points_all, iteration, current_min_iter_third = active_learning.run_active_learning_no_weight_adjustment_high_pred(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count_third += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)


        if True:
            distances_third["Function"].append(function_name)
            distances_third["Distance to Min"].append(gen_def.distance_btw_two_points(min_param, min_function_params)/gen_def.grid_diagonal_distance(range_param))






# Convert the dictionary to a DataFrame
distances_first_df = pd.DataFrame(distances_first)

# Convert the dictionary to a DataFrame
distances_second_df = pd.DataFrame(distances_second)

# Convert the dictionary to a DataFrame
distances_third_df = pd.DataFrame(distances_third)

plt.figure(figsize=(12, 8))

# İlk veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(distances_first_df["Function"], distances_first_df["Distance to Min"])):

    # Scatter plot - kırmızı renk
    plt.scatter(i, proximity, color='red', label="Adjusted Weights" if i == 0 else '')

    # Line plot
    if i < len(min_iter_first_df["Function"]) - 1:
        plt.plot([i, i + 1], [proximity, distances_first_df["Distance to Min"][i + 1]], color='red', linestyle='--')

# İkinci veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(distances_second_df["Function"], distances_second_df["Distance to Min"])):

    # Scatter plot - mavi renk
    plt.scatter(i, proximity, color='blue', label="Low Prediction Weight" if i == 0 else '')

    # Line plot
    if i < len(min_iter_second_df["Function"]) - 1:
        plt.plot([i, i + 1], [proximity, distances_second_df["Distance to Min"][i + 1]], color='blue', linestyle='-.')


# Üçüncü veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(distances_third_df["Function"], distances_third_df["Distance to Min"])):

    # Scatter plot - mavi renk
    plt.scatter(i, proximity, color='green', label="High Prediction Weight" if i == 0 else '')

    # Line plot
    if i < len(min_iter_third_df["Function"]) - 1:
        plt.plot([i, i + 1], [proximity, distances_third_df["Distance to Min"][i + 1]], color='green', linestyle='-.')


# Add labels and legend
plt.xlabel("Function")
plt.ylabel("Distance to Min")
plt.title("Distance to Min by Function")
plt.xticks(range(len(distances_first_df["Function"])), distances_first_df["Function"], rotation=75)
plt.grid(True)
plt.tight_layout()

# Show plot
plt.legend()
plt.show()
# Out:
# Convergence reached at iteration 4.
# Convergence reached at iteration 4.
# Convergence reached at iteration 7.
# Convergence reached at iteration 4.
# Convergence reached at iteration 2.
# Convergence reached at iteration 20.
# Convergence reached at iteration 16.
# Convergence reached at iteration 25.
# Convergence reached at iteration 25.
# Convergence reached at iteration 10.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 8.
# Convergence reached at iteration 4.
# Convergence reached at iteration 10.
# Convergence reached at iteration 7.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 23.
# Convergence reached at iteration 2.
# Convergence reached at iteration 10.
# Convergence reached at iteration 9.
# Convergence reached at iteration 10.
# Convergence reached at iteration 11.
# Convergence reached at iteration 7.
# Convergence reached at iteration 5.
# Convergence reached at iteration 4.
# Convergence reached at iteration 4.
# Convergence reached at iteration 4.
# Convergence reached at iteration 5.
# Convergence reached at iteration 7.
# Convergence reached at iteration 2.
# Convergence reached at iteration 5.
# Convergence reached at iteration 14.
# Convergence reached at iteration 4.
# Convergence reached at iteration 19.
# Convergence reached at iteration 13.
# Convergence reached at iteration 10.
# Convergence reached at iteration 7.
# Convergence reached at iteration 5.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 14.
# Convergence reached at iteration 10.
# Convergence reached at iteration 17.
# Convergence reached at iteration 11.
# Convergence reached at iteration 10.
# Convergence reached at iteration 4.
# Convergence reached at iteration 16.
# Convergence reached at iteration 7.
# Convergence reached at iteration 7.
# Convergence reached at iteration 20.
# Convergence reached at iteration 8.
# Convergence reached at iteration 2.
# Convergence reached at iteration 23.
# Convergence reached at iteration 23.
# Convergence reached at iteration 17.
# Convergence reached at iteration 22.
# Convergence reached at iteration 6.
# Convergence reached at iteration 22.
# Convergence reached at iteration 19.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 16.
# Convergence reached at iteration 8.
# Convergence reached at iteration 19.
# Convergence reached at iteration 2.
# Convergence reached at iteration 16.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 4.
# Convergence reached at iteration 4.
# Convergence reached at iteration 8.
# Convergence reached at iteration 2.
# Convergence reached at iteration 8.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 3.
# Convergence reached at iteration 11.
# Convergence reached at iteration 22.
# Convergence reached at iteration 16.
# Convergence reached at iteration 8.
# Convergence reached at iteration 9.
# Convergence reached at iteration 2.
# Convergence reached at iteration 9.
# Convergence reached at iteration 2.
# Convergence reached at iteration 10.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 18.
# Convergence reached at iteration 18.
# Convergence reached at iteration 18.
# Convergence reached at iteration 2.
# Convergence reached at iteration 2.
# Convergence reached at iteration 3.
# Convergence reached at iteration 2.
# Convergence reached at iteration 4.
# Convergence reached at iteration 18.
# Convergence reached at iteration 10.
# Convergence reached at iteration 4.
# Convergence reached at iteration 12.
# Convergence reached at iteration 6.
# Convergence reached at iteration 10.
# Convergence reached at iteration 2.
# Convergence reached at iteration 10.
# Convergence reached at iteration 4.
# Convergence reached at iteration 5.
# Convergence reached at iteration 12.
# Convergence reached at iteration 12.
# Convergence reached at iteration 24.
# Convergence reached at iteration 9.
# Convergence reached at iteration 17.
# Convergence reached at iteration 2.
# Convergence reached at iteration 12.
# Convergence reached at iteration 10.
# Convergence reached at iteration 18.
# Convergence reached at iteration 18.
# Convergence reached at iteration 15.
