# %%
import numpy as np
import utils.exampleFunctions as ex_func 
import utils.generalDefinitions as gen_def
import utils.models as models
import utils.samplers as samplers
import matplotlib.pyplot as plt
import pandas as pd

# %%
#15 Iterations
# Initial LHS, Candidate LHS
function_names = ex_func.function_ranges.keys()

# Her bir fonksiyon için işlemleri gerçekleştir
number_of_repeats = 1

average_proximities = {
    "Function": [],
    "Average Proximity to Minimum (%)": []
}

for function_name in function_names:
    if True:
    
        proximity_to_minimum_count = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    print(f"Working on function: {function_name}")

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_values, improvement, new_points_all, iteration = active_learning.run_active_learning_constant_iterations_15(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

               
        if True:
            average_iterations = iteration_count/number_of_repeats
            current_average_func = ex_func.function_averages[function_name][0]
            current_minimum_func = ex_func.function_mins[function_name][0]
            average_proximity_to_minimum = proximity_to_minimum_count/number_of_repeats
            

            average_proximity_to_minimum_by_percent = (2*(current_average_func-current_minimum_func)-(average_proximity_to_minimum-current_minimum_func))/(2*(current_average_func-current_minimum_func))
            average_proximities["Function"].append(function_name)
            average_proximities["Average Proximity to Minimum (%)"].append(average_proximity_to_minimum_by_percent)
            #print(average_iterations)
            print(average_proximity_to_minimum_by_percent)

            print("******")
            print("******")
            

# Convert the dictionary to a DataFrame
average_proximities_df = pd.DataFrame(average_proximities)

# Plotting
plt.figure(figsize=(12, 8))
for i, (function, proximity) in enumerate(zip(average_proximities_df["Function"], average_proximities_df["Average Proximity to Minimum (%)"])):
    plt.scatter(i, proximity, label=function)

# Connect points with lines
for i in range(len(average_proximities_df["Function"]) - 1):
    plt.plot([i, i + 1], [average_proximities_df["Average Proximity to Minimum (%)"][i], average_proximities_df["Average Proximity to Minimum (%)"][i + 1]], color='gray', linestyle='--')

# Add labels and legend
plt.xlabel("Function")
plt.ylabel("Average Proximity to Minimum (%)")
plt.title("Average Proximity to Minimum by Function")
plt.xticks(range(len(average_proximities_df["Function"])), average_proximities_df["Function"], rotation=45)
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# Working on function: Ackley
# 0.5603026708224266
# ******
# ******
# Working on function: Bukin
# 0.8709055685650154
# ******
# ******
# Working on function: Cross in Tray
# 0.968290456409577
# ******
# ******
# Working on function: Drop Wave
# 0.6356159521746858
# ******
# ******
# Working on function: Eggholder
# 0.7835085900414298
# ******
# ******
# Working on function: Gramacy Lee
# 0.8952109798564432
# ******
# ******
# Working on function: Holder Table
# 0.8839543921695412
# ******
# ******
# Working on function: Schaffer2
# 0.9079672963768323
# ******
# ******
# Working on function: Schaffer4
# 0.8675561415512439
# ******
# ******
# Working on function: Schwefel
# 0.8793180105258287
# ******
# ******
# Working on function: Shubert
# 0.5978980418111377
# ******
# ******
# Working on function: Bohachevsky
# 0.9735146155884201
# ******
# ******
# Working on function: Rotated Hyper Ellipsoid
# 0.9555368677514828
# ******
# ******
# Working on function: Sphere
# 0.9357615706681756
# ******
# ******
# Working on function: Sum of Different Powers
# 0.5999012837859915
# ******
# ******
# Working on function: Sum Squares
# 0.9774941226731839
# ******
# ******
# Working on function: Trid
# 0.9903357799669826
# ******
# ******
# Working on function: Booth
# 0.937106893004428
# ******
# ******
# Working on function: Matyas
# 0.9785743053479655
# ******
# ******
# Working on function: McCormick
# 0.9882644838802481
# ******
# ******
# Working on function: Three Hump Camel
# 0.9984083731633501
# ******
# ******
# Working on function: Six Hump Camel
# 0.9856344604497186
# ******
# ******
# Working on function: Dixon Price
# 0.9843678290795408
# ******
# ******
# Working on function: Beale
# 0.9997698837573104
# ******
# ******
# Working on function: Branin
# 0.9689610851411181
# ******
# ******
# Working on function: Colville
# 0.9814070145166118
# ******
# ******

# %%
#15 Iterations #multiple
# Initial LHS, Candidate LHS
function_names = ex_func.function_ranges.keys()

# Her bir fonksiyon için işlemleri gerçekleştir
number_of_repeats = 10

average_proximities = {
    "Function": [],
    "Average Proximity to Minimum (%)": []
}

for function_name in function_names:
    if True:
        print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_values, improvement, new_points_all, iteration = active_learning.run_active_learning_constant_iterations_15(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

               
        if True:
            average_iterations = iteration_count/number_of_repeats
            current_average_func = ex_func.function_averages[function_name][0]
            current_minimum_func = ex_func.function_mins[function_name][0]
            average_proximity_to_minimum = proximity_to_minimum_count/number_of_repeats
            

            average_proximity_to_minimum_by_percent = (2*(current_average_func-current_minimum_func)-(average_proximity_to_minimum-current_minimum_func))/(2*(current_average_func-current_minimum_func))
            average_proximities["Function"].append(function_name)
            average_proximities["Average Proximity to Minimum (%)"].append(average_proximity_to_minimum_by_percent)
            #print(average_iterations)
            print(average_proximity_to_minimum_by_percent)

            print("******")
            print("******")
            

# Convert the dictionary to a DataFrame
average_proximities_df = pd.DataFrame(average_proximities)

# Plotting
plt.figure(figsize=(12, 8))
for i, (function, proximity) in enumerate(zip(average_proximities_df["Function"], average_proximities_df["Average Proximity to Minimum (%)"])):
    plt.scatter(i, proximity, label=function)

# Connect points with lines
for i in range(len(average_proximities_df["Function"]) - 1):
    plt.plot([i, i + 1], [average_proximities_df["Average Proximity to Minimum (%)"][i], average_proximities_df["Average Proximity to Minimum (%)"][i + 1]], color='gray', linestyle='--')

# Add labels and legend
plt.xlabel("Function")
plt.ylabel("Average Proximity to Minimum (%)")
plt.title("Average Proximity to Minimum by Function")
plt.xticks(range(len(average_proximities_df["Function"])), average_proximities_df["Function"], rotation=60)
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# Working on function: Ackley
# Working on function: Ackley
# Working on function: Ackley
# Working on function: Ackley
# Working on function: Ackley
# Working on function: Ackley
# Working on function: Ackley
# Working on function: Ackley
# Working on function: Ackley
# Working on function: Ackley
# 0.7745511203473954
# ******
# ******
# Working on function: Bukin
# Working on function: Bukin
# Working on function: Bukin
# Working on function: Bukin
# Working on function: Bukin
# Working on function: Bukin
# Working on function: Bukin
# Working on function: Bukin
# Working on function: Bukin
# Working on function: Bukin
# 0.8310362127285317
# ******
# ******
# Working on function: Cross in Tray
# Working on function: Cross in Tray
# Working on function: Cross in Tray
# Working on function: Cross in Tray
# Working on function: Cross in Tray
# Working on function: Cross in Tray
# Working on function: Cross in Tray
# Working on function: Cross in Tray
# Working on function: Cross in Tray
# Working on function: Cross in Tray
# 0.8393498304779659
# ******
# ******
# Working on function: Drop Wave
# Working on function: Drop Wave
# Working on function: Drop Wave
# Working on function: Drop Wave
# Working on function: Drop Wave
# Working on function: Drop Wave
# Working on function: Drop Wave
# Working on function: Drop Wave
# Working on function: Drop Wave
# Working on function: Drop Wave
# 0.8031807918218358
# ******
# ******
# Working on function: Eggholder
# Working on function: Eggholder
# Working on function: Eggholder
# Working on function: Eggholder
# Working on function: Eggholder
# Working on function: Eggholder
# Working on function: Eggholder
# Working on function: Eggholder
# Working on function: Eggholder
# Working on function: Eggholder
# 0.8785962140191315
# ******
# ******
# Working on function: Gramacy Lee
# Working on function: Gramacy Lee
# Working on function: Gramacy Lee
# Working on function: Gramacy Lee
# Working on function: Gramacy Lee
# Working on function: Gramacy Lee
# Working on function: Gramacy Lee
# Working on function: Gramacy Lee
# Working on function: Gramacy Lee
# Working on function: Gramacy Lee
# 0.9018762351983196
# ******
# ******
# Working on function: Holder Table
# Working on function: Holder Table
# Working on function: Holder Table
# Working on function: Holder Table
# Working on function: Holder Table
# Working on function: Holder Table
# Working on function: Holder Table
# Working on function: Holder Table
# Working on function: Holder Table
# Working on function: Holder Table
# 0.8623694911993437
# ******
# ******
# Working on function: Schaffer2
# Working on function: Schaffer2
# Working on function: Schaffer2
# Working on function: Schaffer2
# Working on function: Schaffer2
# Working on function: Schaffer2
# Working on function: Schaffer2
# Working on function: Schaffer2
# Working on function: Schaffer2
# Working on function: Schaffer2
# 0.6483831750670465
# ******
# ******
# Working on function: Schaffer4
# Working on function: Schaffer4
# Working on function: Schaffer4
# Working on function: Schaffer4
# Working on function: Schaffer4
# Working on function: Schaffer4
# Working on function: Schaffer4
# Working on function: Schaffer4
# Working on function: Schaffer4
# Working on function: Schaffer4
# 0.6407049811508185
# ******
# ******
# Working on function: Schwefel
# Working on function: Schwefel
# Working on function: Schwefel
# Working on function: Schwefel
# Working on function: Schwefel
# Working on function: Schwefel
# Working on function: Schwefel
# Working on function: Schwefel
# Working on function: Schwefel
# Working on function: Schwefel
# 0.8288414688917739
# ******
# ******
# Working on function: Shubert
# Working on function: Shubert
# Working on function: Shubert
# Working on function: Shubert
# Working on function: Shubert
# Working on function: Shubert
# Working on function: Shubert
# Working on function: Shubert
# Working on function: Shubert
# Working on function: Shubert
# 0.7120977107360797
# ******
# ******
# Working on function: Bohachevsky
# Working on function: Bohachevsky
# Working on function: Bohachevsky
# Working on function: Bohachevsky
# Working on function: Bohachevsky
# Working on function: Bohachevsky
# Working on function: Bohachevsky
# Working on function: Bohachevsky
# Working on function: Bohachevsky
# Working on function: Bohachevsky
# 0.9661692835025262
# ******
# ******
# Working on function: Rotated Hyper Ellipsoid
# Working on function: Rotated Hyper Ellipsoid
# Working on function: Rotated Hyper Ellipsoid
# Working on function: Rotated Hyper Ellipsoid
# Working on function: Rotated Hyper Ellipsoid
# Working on function: Rotated Hyper Ellipsoid
# Working on function: Rotated Hyper Ellipsoid
# Working on function: Rotated Hyper Ellipsoid
# Working on function: Rotated Hyper Ellipsoid
# Working on function: Rotated Hyper Ellipsoid
# 0.9647714307235468
# ******
# ******
# Working on function: Sphere
# Working on function: Sphere
# Working on function: Sphere
# Working on function: Sphere
# Working on function: Sphere
# Working on function: Sphere
# Working on function: Sphere
# Working on function: Sphere
# Working on function: Sphere
# Working on function: Sphere
# 0.965400601217437
# ******
# ******
# Working on function: Sum of Different Powers
# Working on function: Sum of Different Powers
# Working on function: Sum of Different Powers
# Working on function: Sum of Different Powers
# Working on function: Sum of Different Powers
# Working on function: Sum of Different Powers
# Working on function: Sum of Different Powers
# Working on function: Sum of Different Powers
# Working on function: Sum of Different Powers
# Working on function: Sum of Different Powers
# 0.8105430436317536
# ******
# ******
# Working on function: Sum Squares
# Working on function: Sum Squares
# Working on function: Sum Squares
# Working on function: Sum Squares
# Working on function: Sum Squares
# Working on function: Sum Squares
# Working on function: Sum Squares
# Working on function: Sum Squares
# Working on function: Sum Squares
# Working on function: Sum Squares
# 0.9600772503029392
# ******
# ******
# Working on function: Trid
# Working on function: Trid
# Working on function: Trid
# Working on function: Trid
# Working on function: Trid
# Working on function: Trid
# Working on function: Trid
# Working on function: Trid
# Working on function: Trid
# Working on function: Trid
# 0.9802997349350754
# ******
# ******
# Working on function: Booth
# Working on function: Booth
# Working on function: Booth
# Working on function: Booth
# Working on function: Booth
# Working on function: Booth
# Working on function: Booth
# Working on function: Booth
# Working on function: Booth
# Working on function: Booth
# 0.970799292982748
# ******
# ******
# Working on function: Matyas
# Working on function: Matyas
# Working on function: Matyas
# Working on function: Matyas
# Working on function: Matyas
# Working on function: Matyas
# Working on function: Matyas
# Working on function: Matyas
# Working on function: Matyas
# Working on function: Matyas
# 0.9740374218050981
# ******
# ******
# Working on function: McCormick
# Working on function: McCormick
# Working on function: McCormick
# Working on function: McCormick
# Working on function: McCormick
# Working on function: McCormick
# Working on function: McCormick
# Working on function: McCormick
# Working on function: McCormick
# Working on function: McCormick
# 0.9767319985225827
# ******
# ******
# Working on function: Three Hump Camel
# Working on function: Three Hump Camel
# Working on function: Three Hump Camel
# Working on function: Three Hump Camel
# Working on function: Three Hump Camel
# Working on function: Three Hump Camel
# Working on function: Three Hump Camel
# Working on function: Three Hump Camel
# Working on function: Three Hump Camel
# Working on function: Three Hump Camel
# 0.9974074891536109
# ******
# ******
# Working on function: Six Hump Camel
# Working on function: Six Hump Camel
# Working on function: Six Hump Camel
# Working on function: Six Hump Camel
# Working on function: Six Hump Camel
# Working on function: Six Hump Camel
# Working on function: Six Hump Camel
# Working on function: Six Hump Camel
# Working on function: Six Hump Camel
# Working on function: Six Hump Camel
# 0.9865005227842424
# ******
# ******
# Working on function: Dixon Price
# Working on function: Dixon Price
# Working on function: Dixon Price
# Working on function: Dixon Price
# Working on function: Dixon Price
# Working on function: Dixon Price
# Working on function: Dixon Price
# Working on function: Dixon Price
# Working on function: Dixon Price
# Working on function: Dixon Price
# 0.916317851039759
# ******
# ******
# Working on function: Beale
# Working on function: Beale
# Working on function: Beale
# Working on function: Beale
# Working on function: Beale
# Working on function: Beale
# Working on function: Beale
# Working on function: Beale
# Working on function: Beale
# Working on function: Beale
# 0.9997158406433226
# ******
# ******
# Working on function: Branin
# Working on function: Branin
# Working on function: Branin
# Working on function: Branin
# Working on function: Branin
# Working on function: Branin
# Working on function: Branin
# Working on function: Branin
# Working on function: Branin
# Working on function: Branin
# 0.9753248381644892
# ******
# ******
# Working on function: Colville
# Working on function: Colville
# Working on function: Colville
# Working on function: Colville
# Working on function: Colville
# Working on function: Colville
# Working on function: Colville
# Working on function: Colville
# Working on function: Colville
# Working on function: Colville
# 0.9910267943490221
# ******
# ******

# %%
#üst üste,15,25,50
#15 Iterations #multiple
# Initial LHS, Candidate LHS
function_names = ex_func.function_ranges.keys()

# Her bir fonksiyon için işlemleri gerçekleştir
number_of_repeats = 1

average_proximities = {
    "Function": [],
    "Average Proximity to Minimum (%)": []
}
average_proximities_second = {
    "Function": [],
    "Average Proximity to Minimum (%)": []
}
average_proximities_third = {
    "Function": [],
    "Average Proximity to Minimum (%)": []
}

for function_name in function_names:
    if True:
        print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_values, improvement, new_points_all, iteration = active_learning.run_active_learning_constant_iterations_15(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

               
        if True:
            average_iterations = iteration_count/number_of_repeats
            current_average_func = ex_func.function_averages[function_name][0]
            current_minimum_func = ex_func.function_mins[function_name][0]
            average_proximity_to_minimum = proximity_to_minimum_count/number_of_repeats
            

            average_proximity_to_minimum_by_percent = (2*(current_average_func-current_minimum_func)-(average_proximity_to_minimum-current_minimum_func))/(2*(current_average_func-current_minimum_func))
            average_proximities["Function"].append(function_name)
            average_proximities["Average Proximity to Minimum (%)"].append(average_proximity_to_minimum_by_percent)
            #print(average_iterations)
            print(average_proximity_to_minimum_by_percent)

            print("******")
            print("******")
            

for function_name in function_names:
    if True:
        print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count_second = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_values, improvement, new_points_all, iteration = active_learning.run_active_learning_constant_iterations_25(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count_second += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

               
        if True:
            average_iterations = iteration_count/number_of_repeats
            current_average_func = ex_func.function_averages[function_name][0]
            current_minimum_func = ex_func.function_mins[function_name][0]
            average_proximity_to_minimum_second = proximity_to_minimum_count_second/number_of_repeats
            

            average_proximity_to_minimum_by_percent_second = (2*(current_average_func-current_minimum_func)-(average_proximity_to_minimum_second-current_minimum_func))/(2*(current_average_func-current_minimum_func))
            average_proximities_second["Function"].append(function_name)
            average_proximities_second["Average Proximity to Minimum (%)"].append(average_proximity_to_minimum_by_percent_second)
            #print(average_iterations)
            print(average_proximity_to_minimum_by_percent_second)

            print("******")
            print("******")

for function_name in function_names:
    if True:
        print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count_third = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_values, improvement, new_points_all, iteration = active_learning.run_active_learning_constant_iterations_50(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count_third += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

               
        if True:
            average_iterations = iteration_count/number_of_repeats
            current_average_func = ex_func.function_averages[function_name][0]
            current_minimum_func = ex_func.function_mins[function_name][0]
            average_proximity_to_minimum_third = proximity_to_minimum_count_third/number_of_repeats
            

            average_proximity_to_minimum_by_percent_third = (2*(current_average_func-current_minimum_func)-(average_proximity_to_minimum_third-current_minimum_func))/(2*(current_average_func-current_minimum_func))
            average_proximities_third["Function"].append(function_name)
            average_proximities_third["Average Proximity to Minimum (%)"].append(average_proximity_to_minimum_by_percent_third)
            #print(average_iterations)
            print(average_proximity_to_minimum_by_percent_third)

            print("******")
            print("******")








# Convert the dictionary to a DataFrame
average_proximities_df = pd.DataFrame(average_proximities)

# Convert the dictionary to a DataFrame
average_proximities_df_second = pd.DataFrame(average_proximities_second)

# Convert the dictionary to a DataFrame
average_proximities_df_third = pd.DataFrame(average_proximities_third)

# Plotting
# Plotting
plt.figure(figsize=(12, 8))

# İlk veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(average_proximities_df["Function"], average_proximities_df["Average Proximity to Minimum (%)"])):
    plt.scatter(i, proximity, label=function)

for i in range(len(average_proximities_df["Function"]) - 1):
    plt.plot([i, i + 1], [average_proximities_df["Average Proximity to Minimum (%)"][i], average_proximities_df["Average Proximity to Minimum (%)"][i + 1]], color='gray', linestyle='--')

# İkinci veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(average_proximities_df_second["Function"], average_proximities_df_second["Average Proximity to Minimum (%)"])):
    plt.scatter(i, proximity, label=function)

for i in range(len(average_proximities_df_second["Function"]) - 1):
    plt.plot([i, i + 1], [average_proximities_df_second["Average Proximity to Minimum (%)"][i], average_proximities_df_second["Average Proximity to Minimum (%)"][i + 1]], color='blue', linestyle='--')

# İkinci veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(average_proximities_df_third["Function"], average_proximities_df_third["Average Proximity to Minimum (%)"])):
    plt.scatter(i, proximity, label=function)

for i in range(len(average_proximities_df_third["Function"]) - 1):
    plt.plot([i, i + 1], [average_proximities_df_third["Average Proximity to Minimum (%)"][i], average_proximities_df_third["Average Proximity to Minimum (%)"][i + 1]], color='red', linestyle='--')

# Add labels and legend
plt.xlabel("Function")
plt.ylabel("Average Proximity to Minimum (%)")
plt.title("Average Proximity to Minimum by Function")
plt.xticks(range(len(average_proximities_df["Function"])), average_proximities_df["Function"], rotation=75)
plt.grid(True)
plt.tight_layout()
plt.legend(["First Dataset", "Second Dataset", "Third Dataset"])

# Show plot
plt.show()
# Out:
# Working on function: Ackley
# 0.7504098007238765
# ******
# ******
# Working on function: Bukin
# 0.7926458301630356
# ******
# ******
# Working on function: Cross in Tray
# 0.8411355535716061
# ******
# ******
# Working on function: Drop Wave
# 0.7687886036319974
# ******
# ******
# Working on function: Eggholder
# 0.8203709191053355
# ******
# ******
# Working on function: Gramacy Lee
# 0.8942420773440788
# ******
# ******
# Working on function: Holder Table
# 0.9684165555501756
# ******
# ******
# Working on function: Schaffer2
# 0.5079008276463909
# ******
# ******
# Working on function: Schaffer4
# 0.6418983378041506
# ******
# ******
# Working on function: Schwefel
# 0.7255981187652705
# ******
# ******
# Working on function: Shubert
# 0.6633833560123021
# ******
# ******
# Working on function: Bohachevsky
# 0.9739867889810682
# ******
# ******
# Working on function: Rotated Hyper Ellipsoid
# 0.9718928927993346
# ******
# ******
# Working on function: Sphere
# 0.9985484568846409
# ******
# ******
# Working on function: Sum of Different Powers
# 0.8032551325867316
# ******
# ******
# Working on function: Sum Squares
# 0.91590428777253
# ******
# ******
# Working on function: Trid
# 0.9792517438636615
# ******
# ******
# Working on function: Booth
# 0.9760798508631017
# ******
# ******
# Working on function: Matyas
# 0.9936371491424711
# ******
# ******
# Working on function: McCormick
# 0.9907452012193058
# ******
# ******
# Working on function: Three Hump Camel
# 0.9980121631819501
# ******
# ******
# Working on function: Six Hump Camel
# 0.9857649593948287
# ******
# ******
# Working on function: Dixon Price
# 0.9684182726695882
# ******
# ******
# Working on function: Beale
# 0.9999221348195321
# ******
# ******
# Working on function: Branin
# 0.9816301650719692
# ******
# ******
# Working on function: Colville
# 0.9863837151759628
# ******
# ******
# Working on function: Ackley
# 0.9227196247903058
# ******
# ******
# Working on function: Bukin
# 0.9130573552744681
# ******
# ******
# Working on function: Cross in Tray
# 0.8381565431077403
# ******
# ******
# Working on function: Drop Wave
# 0.8765270571747088
# ******
# ******
# Working on function: Eggholder
# 0.9609008932791719
# ******
# ******
# Working on function: Gramacy Lee
# 0.9203293541175995
# ******
# ******
# Working on function: Holder Table
# 0.9543700165328499
# ******
# ******
# Working on function: Schaffer2
# 0.5771526627436149
# ******
# ******
# Working on function: Schaffer4
# 0.6123008868477255
# ******
# ******
# Working on function: Schwefel
# 0.7623147682418472
# ******
# ******
# Working on function: Shubert
# 0.9233408137284943
# ******
# ******
# Working on function: Bohachevsky
# 0.9938890052723094
# ******
# ******
# Working on function: Rotated Hyper Ellipsoid
# 0.9641094493861345
# ******
# ******
# Working on function: Sphere
# 0.9892917887503837
# ******
# ******
# Working on function: Sum of Different Powers
# 0.9733172225099338
# ******
# ******
# Working on function: Sum Squares
# 0.9838285810947567
# ******
# ******
# Working on function: Trid
# 0.9850324814433007
# ******
# ******
# Working on function: Booth
# 0.990945019318936
# ******
# ******
# Working on function: Matyas
# 0.9954972551119277
# ******
# ******
# Working on function: McCormick
# 0.9864667181106072
# ******
# ******
# Working on function: Three Hump Camel
# 0.998286573329977
# ******
# ******
# Working on function: Six Hump Camel
# 0.9856235752944407
# ******
# ******
# Working on function: Dixon Price
# 0.9944640294402793
# ******
# ******
# Working on function: Beale
# 0.9997985236535746
# ******
# ******
# Working on function: Branin
# 0.9924253401383414
# ******
# ******
# Working on function: Colville
# 0.9916432445002035
# ******
# ******
# Working on function: Ackley
# 0.9420356111188234
# ******
# ******
# Working on function: Bukin
# 0.9882562201220636
# ******
# ******
# Working on function: Cross in Tray
# 0.9733502432675372
# ******
# ******
# Working on function: Drop Wave
# 0.8764590315783635
# ******
# ******
# Working on function: Eggholder
# 0.9432875367825435
# ******
# ******
# Working on function: Gramacy Lee
# 0.9995335149187432
# ******
# ******
# Working on function: Holder Table
# 0.9998210221576461
# ******
# ******
# Working on function: Schaffer2
# 0.6315915735811717
# ******
# ******
# Working on function: Schaffer4
# 0.6006825511771693
# ******
# ******
# Working on function: Schwefel
# 0.9292724104209344
# ******
# ******
# Working on function: Shubert
# 0.9889775509773016
# ******
# ******
# Working on function: Bohachevsky
# 0.9979608985159173
# ******
# ******
# Working on function: Rotated Hyper Ellipsoid
# 0.9939057949936003
# ******
# ******
# Working on function: Sphere
# 0.9982644463189535
# ******
# ******
# Working on function: Sum of Different Powers
# 0.8582930639553796
# ******
# ******
# Working on function: Sum Squares
# 0.9989611765522398
# ******
# ******
# Working on function: Trid
# 0.9988226534862952
# ******
# ******
# Working on function: Booth
# 0.999411163246561
# ******
# ******
# Working on function: Matyas
# 0.9928436646867443
# ******
# ******
# Working on function: McCormick
# 0.9917365982632442
# ******
# ******
# Working on function: Three Hump Camel
# 0.9996676225097758
# ******
# ******
# Working on function: Six Hump Camel
# 0.9984774856749781
# ******
# ******
# Working on function: Dixon Price
# 0.9905626963780418
# ******
# ******
# Working on function: Beale
# 0.9999302925350132
# ******
# ******
# Working on function: Branin
# 0.9957192393950314
# ******
# ******
# Working on function: Colville
# 0.9983329442112149
# ******
# ******

# %%
#üst üste: 25,50,100
#15 Iterations #multiple
# Initial LHS, Candidate LHS
function_names = ex_func.function_ranges.keys()

# Her bir fonksiyon için işlemleri gerçekleştir
number_of_repeats = 1

average_proximities = {
    "Function": [],
    "Average Proximity to Minimum (%)": []
}
average_proximities_second = {
    "Function": [],
    "Average Proximity to Minimum (%)": []
}
average_proximities_third = {
    "Function": [],
    "Average Proximity to Minimum (%)": []
}

for function_name in function_names:
    if True:
        print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_values, improvement, new_points_all, iteration = active_learning.run_active_learning_constant_iterations_15(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

               
        if True:
            average_iterations = iteration_count/number_of_repeats
            current_average_func = ex_func.function_averages[function_name][0]
            current_minimum_func = ex_func.function_mins[function_name][0]
            average_proximity_to_minimum = proximity_to_minimum_count/number_of_repeats
            

            average_proximity_to_minimum_by_percent = (2*(current_average_func-current_minimum_func)-(average_proximity_to_minimum-current_minimum_func))/(2*(current_average_func-current_minimum_func))
            average_proximities["Function"].append(function_name)
            average_proximities["Average Proximity to Minimum (%)"].append(average_proximity_to_minimum_by_percent)
            #print(average_iterations)
            print(average_proximity_to_minimum_by_percent)

            print("******")
            print("******")
            

for function_name in function_names:
    if True:
        print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count_second = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_values, improvement, new_points_all, iteration = active_learning.run_active_learning_constant_iterations_50(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count_second += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

               
        if True:
            average_iterations = iteration_count/number_of_repeats
            current_average_func = ex_func.function_averages[function_name][0]
            current_minimum_func = ex_func.function_mins[function_name][0]
            average_proximity_to_minimum_second = proximity_to_minimum_count_second/number_of_repeats
            

            average_proximity_to_minimum_by_percent_second = (2*(current_average_func-current_minimum_func)-(average_proximity_to_minimum_second-current_minimum_func))/(2*(current_average_func-current_minimum_func))
            average_proximities_second["Function"].append(function_name)
            average_proximities_second["Average Proximity to Minimum (%)"].append(average_proximity_to_minimum_by_percent_second)
            #print(average_iterations)
            print(average_proximity_to_minimum_by_percent_second)

            print("******")
            print("******")

for function_name in function_names:
    if True:
        print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count_third = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_values, improvement, new_points_all, iteration = active_learning.run_active_learning_constant_iterations(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count_third += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

               
        if True:
            average_iterations = iteration_count/number_of_repeats
            current_average_func = ex_func.function_averages[function_name][0]
            current_minimum_func = ex_func.function_mins[function_name][0]
            average_proximity_to_minimum_third = proximity_to_minimum_count_third/number_of_repeats
            

            average_proximity_to_minimum_by_percent_third = (2*(current_average_func-current_minimum_func)-(average_proximity_to_minimum_third-current_minimum_func))/(2*(current_average_func-current_minimum_func))
            average_proximities_third["Function"].append(function_name)
            average_proximities_third["Average Proximity to Minimum (%)"].append(average_proximity_to_minimum_by_percent_third)
            #print(average_iterations)
            print(average_proximity_to_minimum_by_percent_third)

            print("******")
            print("******")








# Convert the dictionary to a DataFrame
average_proximities_df = pd.DataFrame(average_proximities)

# Convert the dictionary to a DataFrame
average_proximities_df_second = pd.DataFrame(average_proximities_second)

# Convert the dictionary to a DataFrame
average_proximities_df_third = pd.DataFrame(average_proximities_third)

# Plotting
# Plotting
plt.figure(figsize=(12, 8))

# İlk veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(average_proximities_df["Function"], average_proximities_df["Average Proximity to Minimum (%)"])):
    plt.scatter(i, proximity, label=function)

for i in range(len(average_proximities_df["Function"]) - 1):
    plt.plot([i, i + 1], [average_proximities_df["Average Proximity to Minimum (%)"][i], average_proximities_df["Average Proximity to Minimum (%)"][i + 1]], color='gray', linestyle='--')

# İkinci veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(average_proximities_df_second["Function"], average_proximities_df_second["Average Proximity to Minimum (%)"])):
    plt.scatter(i, proximity, label=function)

for i in range(len(average_proximities_df_second["Function"]) - 1):
    plt.plot([i, i + 1], [average_proximities_df_second["Average Proximity to Minimum (%)"][i], average_proximities_df_second["Average Proximity to Minimum (%)"][i + 1]], color='blue', linestyle='--')

# İkinci veri kümesini çizdirme
for i, (function, proximity) in enumerate(zip(average_proximities_df_third["Function"], average_proximities_df_third["Average Proximity to Minimum (%)"])):
    plt.scatter(i, proximity, label=function)

for i in range(len(average_proximities_df_third["Function"]) - 1):
    plt.plot([i, i + 1], [average_proximities_df_third["Average Proximity to Minimum (%)"][i], average_proximities_df_third["Average Proximity to Minimum (%)"][i + 1]], color='red', linestyle='--')

# Add labels and legend
plt.xlabel("Function")
plt.ylabel("Average Proximity to Minimum (%)")
plt.title("Average Proximity to Minimum by Function")
plt.xticks(range(len(average_proximities_df["Function"])), average_proximities_df["Function"], rotation=75)
plt.grid(True)
plt.tight_layout()
plt.legend(["First Dataset", "Second Dataset", "Third Dataset"])

# Show plot
plt.show()
# Out:
# Working on function: Ackley
# 0.8577088104546888
# ******
# ******
# Working on function: Bukin
# 0.8757606340780766
# ******
# ******
# Working on function: Cross in Tray
# 0.8972753703884393
# ******
# ******
# Working on function: Drop Wave
# 0.8881812338329124
# ******
# ******
# Working on function: Eggholder
# 0.6896177308356627
# ******
# ******
# Working on function: Gramacy Lee
# 0.946298737069622
# ******
# ******
# Working on function: Holder Table
# 0.787436325364858
# ******
# ******
# Working on function: Schaffer2
# 0.7787558154424391
# ******
# ******
# Working on function: Schaffer4
# 0.5928468533233194
# ******
# ******
# Working on function: Schwefel
# 0.8728445382570602
# ******
# ******
# Working on function: Shubert
# 0.5638160476657055
# ******
# ******
# Working on function: Bohachevsky
# 0.8746396869039885
# ******
# ******
# Working on function: Rotated Hyper Ellipsoid
# 0.9410387535508805
# ******
# ******
# Working on function: Sphere
# 0.956836074179661
# ******
# ******
# Working on function: Sum of Different Powers
# 0.9458720812793462
# ******
# ******
# Working on function: Sum Squares
# 0.921295922192811
# ******
# ******
# Working on function: Trid
# 0.9686955127549712
# ******
# ******
# Working on function: Booth
# 0.977429071280162
# ******
# ******
# Working on function: Matyas
# 0.9438265076331369
# ******
# ******
# Working on function: McCormick
# 0.9988381309905
# ******
# ******
# Working on function: Three Hump Camel
# 0.9982606302790042
# ******
# ******
# Working on function: Six Hump Camel
# 0.9809380498178131
# ******
# ******
# Working on function: Dixon Price
# 0.9190998636856779
# ******
# ******
# Working on function: Beale
# 0.9997942885222669
# ******
# ******
# Working on function: Branin
# 0.9580005525615578
# ******
# ******
# Working on function: Colville
# 0.8846626543558626
# ******
# ******
# Working on function: Ackley
# 0.9303056822231822
# ******
# ******
# Working on function: Bukin
# 0.9914315323961961
# ******
# ******
# Working on function: Cross in Tray
# 0.9789056837826985
# ******
# ******
# Working on function: Drop Wave
# 0.9611164122486131
# ******
# ******
# Working on function: Eggholder
# 0.965460789601607
# ******
# ******
# Working on function: Gramacy Lee
# 0.9991721725564021
# ******
# ******
# Working on function: Holder Table
# 0.9993730157045094
# ******
# ******
# Working on function: Schaffer2
# 0.7703788586544559
# ******
# ******
# Working on function: Schaffer4
# 0.64535929112222
# ******
# ******
# Working on function: Schwefel
# 0.9111993076447932
# ******
# ******
# Working on function: Shubert
# 0.9936785142344343
# ******
# ******
# Working on function: Bohachevsky
# 0.9986211236225667
# ******
# ******
# Working on function: Rotated Hyper Ellipsoid
# 0.9987266503627958
# ******
# ******
# Working on function: Sphere
# 0.9958802161948872
# ******
# ******
# Working on function: Sum of Different Powers
# 0.7870466646547314
# ******
# ******
# Working on function: Sum Squares
# 0.9972464014304109
# ******
# ******
# Working on function: Trid
# 0.9980550505795994
# ******
# ******
# Working on function: Booth
# 0.9994573738152743
# ******
# ******
# Working on function: Matyas
# 0.9992135139530975
# ******
# ******
# Working on function: McCormick
# 0.9953352172177309
# ******
# ******
# Working on function: Three Hump Camel
# 0.9993321482868094
# ******
# ******
# Working on function: Six Hump Camel
# 0.996859409265704
# ******
# ******
# Working on function: Dixon Price
# 0.9657901467239349
# ******
# ******
# Working on function: Beale
# 0.9998508903547583
# ******
# ******
# Working on function: Branin
# 0.9893655887517954
# ******
# ******
# Working on function: Colville
# 0.9992863035151944
# ******
# ******
# Working on function: Ackley
# 0.9974514405132187
# ******
# ******
# Working on function: Bukin
# 0.9906371093889984
# ******
# ******
# Working on function: Cross in Tray
# 0.9993578327624317
# ******
# ******
# Working on function: Drop Wave
# 0.9632563766877844
# ******
# ******
# Working on function: Eggholder
# 0.9983219357278917
# ******
# ******
# Working on function: Gramacy Lee
# 1.0000028068724292
# ******
# ******
# Working on function: Holder Table
# 0.9999055065034081
# ******
# ******
# Working on function: Schaffer2
# 0.860105783918193
# ******
# ******
# Working on function: Schaffer4
# 0.9320547089559833
# ******
# ******
# Working on function: Schwefel
# 0.999915651096458
# ******
# ******
# Working on function: Shubert
# 0.9922414793727488
# ******
# ******
# Working on function: Bohachevsky
# 0.9999235280632052
# ******
# ******
# Working on function: Rotated Hyper Ellipsoid
# 0.9999002872650039
# ******
# ******
# Working on function: Sphere
# 0.9999166583904308
# ******
# ******
# Working on function: Sum of Different Powers
# 0.9961657041581284
# ******
# ******
# Working on function: Sum Squares
# 0.9999497483083455
# ******
# ******
# Working on function: Trid
# 0.9999685804027576
# ******
# ******
# Working on function: Booth
# 0.9997089416447223
# ******
# ******
# Working on function: Matyas
# 0.9998737332049684
# ******
# ******
# Working on function: McCormick
# 0.99990073364775
# ******
# ******
# Working on function: Three Hump Camel
# 0.9998280818700095
# ******
# ******
# Working on function: Six Hump Camel
# 0.9995519319111498
# ******
# ******
# Working on function: Dixon Price
# 0.9992125483895862
# ******
# ******
# Working on function: Beale
# 0.9999672043732343
# ******
# ******
# Working on function: Branin
# 0.9986689160319239
# ******
# ******
# Working on function: Colville
# 0.9994404098576462
# ******
# ******

# %%
#üst üste, 2 çizgi
#bar chart
# Initial LHS, Candidate LHS
function_names = ex_func.function_ranges.keys()

# Her bir fonksiyon için işlemleri gerçekleştir
number_of_repeats = 1

average_proximities = {
    "Function": [],
    "Average Proximity to Minimum (%)": []
}
average_proximities_second = {
    "Function": [],
    "Average Proximity to Minimum (%)": []
}


for function_name in function_names:
    if True:
        print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_values, improvement, new_points_all, iteration = active_learning.run_active_learning_constant_iterations_15(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

               
        if True:
            average_iterations = iteration_count/number_of_repeats
            current_average_func = ex_func.function_averages[function_name][0]
            current_minimum_func = ex_func.function_mins[function_name][0]
            average_proximity_to_minimum = proximity_to_minimum_count/number_of_repeats
            

            average_proximity_to_minimum_by_percent = (2*(current_average_func-current_minimum_func)-(average_proximity_to_minimum-current_minimum_func))/(2*(current_average_func-current_minimum_func))
            average_proximities["Function"].append(function_name)
            average_proximities["Average Proximity to Minimum (%)"].append(average_proximity_to_minimum_by_percent)
            #print(average_iterations)
            print(average_proximity_to_minimum_by_percent)

            print("******")
            print("******")
            

for function_name in function_names:
    if True:
        print(f"Working on function: {function_name}")
    
        proximity_to_minimum_count_second = 0
        for i in range(number_of_repeats):
            iteration_count = 0
            if True:
                    
                try:
                    

                    function_param = getattr(ex_func, function_name.lower().replace(" ", "_"))

                    # Aralığı al
                    range_param = ex_func.function_ranges[function_name]


                    # Generate initial samples
                    sampler = samplers.LatinHypercubeSampling(function_param)
                    initial_points = sampler.sample(num_samples=5, ranges=range_param)
                    initial_values = np.array([function_param(i) for i in initial_points])

                    # Train the initial model using random forests
                    rf_model = models.RandomForestModel(n_estimators=200, random_state=1729)
                    rf_model.train_model(initial_points, initial_values)
                    trained_rf_model = rf_model.get_model()

                    # Perform active learning
                    active_learning = models.ActiveLearning(initial_points, initial_values, rf_model, sampler)
                    min_function_values, improvement, new_points_all, iteration = active_learning.run_active_learning_constant_iterations_25(2000, range_param, 3)
                    iteration_count += iteration
                    minimum_value_so_far = min(min_function_values)
                    
                    current_proximity =  minimum_value_so_far 
                    proximity_to_minimum_count_second += current_proximity
                    #print(proximity_to_minimum_count)

                    

                    #print(f"Actual global min value is: {ex_func.function_mins[function_name]}")
                
                    
                
                except Exception as e:
                    print(f"{function_name} function failed.")
                    print(e)

               
        if True:
            average_iterations = iteration_count/number_of_repeats
            current_average_func = ex_func.function_averages[function_name][0]
            current_minimum_func = ex_func.function_mins[function_name][0]
            average_proximity_to_minimum_second = proximity_to_minimum_count_second/number_of_repeats
            

            average_proximity_to_minimum_by_percent_second = (2*(current_average_func-current_minimum_func)-(average_proximity_to_minimum_second-current_minimum_func))/(2*(current_average_func-current_minimum_func))
            average_proximities_second["Function"].append(function_name)
            average_proximities_second["Average Proximity to Minimum (%)"].append(average_proximity_to_minimum_by_percent_second)
            #print(average_iterations)
            print(average_proximity_to_minimum_by_percent_second)

            print("******")
            print("******")










# Convert the dictionary to a DataFrame
average_proximities_df = pd.DataFrame(average_proximities)

# Convert the dictionary to a DataFrame
average_proximities_df_second = pd.DataFrame(average_proximities_second)



# Plotting
# Plotting
# Çubuk grafik oluşturma
plt.figure(figsize=(12, 8))

# İlk veri kümesinin çubuklarını çizme
bar_width = 0.35
index = np.arange(len(average_proximities_df["Function"]))
plt.bar(index, average_proximities_df["Average Proximity to Minimum (%)"], bar_width, label='First Dataset')

# İkinci veri kümesinin çubuklarını çizme
plt.bar(index + bar_width, average_proximities_df_second["Average Proximity to Minimum (%)"], bar_width, label='Second Dataset')

# Eksen etiketleri, başlık ve görsel ayarları
plt.xlabel("Function")
plt.ylabel("Average Proximity to Minimum (%)")
plt.title("Average Proximity to Minimum by Function")
plt.xticks(index + bar_width / 2, average_proximities_df["Function"], rotation=75)
plt.grid(True)
plt.tight_layout()
plt.legend()

# Grafiği gösterme
plt.show()
# Out:
# Working on function: Ackley
# 0.9244786969295796
# ******
# ******
# Working on function: Bukin
# 0.8981327640452831
# ******
# ******
# Working on function: Cross in Tray
# 0.7102914122607015
# ******
# ******
# Working on function: Drop Wave
# 0.771419983405327
# ******
# ******
# Working on function: Eggholder
# 0.8844646899380947
# ******
# ******
# Working on function: Gramacy Lee
# 0.8569936527451945
# ******
# ******
# Working on function: Holder Table
# 0.7570041327401558
# ******
# ******
# Working on function: Schaffer2
# 0.5149666680611804
# ******
# ******
# Working on function: Schaffer4
# 0.5986164680847232
# ******
# ******
# Working on function: Schwefel
# 0.8255327982217752
# ******
# ******
# Working on function: Shubert
# 0.5807019936071153
# ******
# ******
# Working on function: Bohachevsky
# 0.9718875462113066
# ******
# ******
# Working on function: Rotated Hyper Ellipsoid
# 0.9987309052771003
# ******
# ******
# Working on function: Sphere
# 0.9332909301909523
# ******
# ******
# Working on function: Sum of Different Powers
# 0.8890325507370239
# ******
# ******
# Working on function: Sum Squares
# 0.9840387798765134
# ******
# ******
# Working on function: Trid
# 0.9666520372954134
# ******
# ******
# Working on function: Booth
# 0.9543562956175308
# ******
# ******
# Working on function: Matyas
# 0.96805129415508
# ******
# ******
# Working on function: McCormick
# 0.9729643919432007
# ******
# ******
# Working on function: Three Hump Camel
# 0.9959410506614156
# ******
# ******
# Working on function: Six Hump Camel
# 0.9778965824945263
# ******
# ******
# Working on function: Dixon Price
# 0.8744465526819057
# ******
# ******
# Working on function: Beale
# 0.9997546093115421
# ******
# ******
# Working on function: Branin
# 0.992486950403529
# ******
# ******
# Working on function: Colville
# 0.9938102610608853
# ******
# ******
# Working on function: Ackley
# 0.8354701667306197
# ******
# ******
# Working on function: Bukin
# 0.8480765684471189
# ******
# ******
# Working on function: Cross in Tray
# 0.8931695888983399
# ******
# ******
# Working on function: Drop Wave
# 0.682027127382344
# ******
# ******
# Working on function: Eggholder
# 0.8222940976363674
# ******
# ******
# Working on function: Gramacy Lee
# 0.9849662311438862
# ******
# ******
# Working on function: Holder Table
# 0.9843090992670491
# ******
# ******
# Working on function: Schaffer2
# 0.5934667602911312
# ******
# ******
# Working on function: Schaffer4
# 0.8944917429433612
# ******
# ******
# Working on function: Schwefel
# 0.9389088143721196
# ******
# ******
# Working on function: Shubert
# 0.7816563728846685
# ******
# ******
# Working on function: Bohachevsky
# 0.9908187427497113
# ******
# ******
# Working on function: Rotated Hyper Ellipsoid
# 0.9933860017027825
# ******
# ******
# Working on function: Sphere
# 0.9752594526320503
# ******
# ******
# Working on function: Sum of Different Powers
# 0.7250023052195423
# ******
# ******
# Working on function: Sum Squares
# 0.998466855304048
# ******
# ******
# Working on function: Trid
# 0.9997543833804318
# ******
# ******
# Working on function: Booth
# 0.9870074178355299
# ******
# ******
# Working on function: Matyas
# 0.9977881335996116
# ******
# ******
# Working on function: McCormick
# 0.9700372606272233
# ******
# ******
# Working on function: Three Hump Camel
# 0.9979490937265313
# ******
# ******
# Working on function: Six Hump Camel
# 0.9879137868066152
# ******
# ******
# Working on function: Dixon Price
# 0.9655386667122173
# ******
# ******
# Working on function: Beale
# 0.9998196101315634
# ******
# ******
# Working on function: Branin
# 0.9781217731021111
# ******
# ******
# Working on function: Colville
# 0.9880924819479219
# ******
# ******
